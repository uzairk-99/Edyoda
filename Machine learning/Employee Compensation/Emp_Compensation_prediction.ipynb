# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Reading from url
url = 'https://drive.google.com/file/d/1mSkKEe0SUJ7AZHiubxKSke7HWf75JA_Z/view'

# %%
f_id=url.split('/')[-2]

# %%
f_url='https://drive.google.com/uc?id='+f_id

# %%
df = pd.read_csv(f_url)

# %%
# Reading the dataset if file downloaded in current directory

#df = pd.read_csv('train_set.csv')

# %%
df
# Out:
#         Year  OGC                                        OG   DC  \
# 0       2015    4                          Community Health  DPH
# 1       2013    4                          Community Health  DPH
# 2       2015    6          General Administration & Finance  ASR
# 3       2016    1                         Public Protection  POL
# 4       2013    2   Public Works, Transportation & Commerce  HHP
# ...      ...  ...                                       ...  ...
# 287831  2016    3  Human Welfare & Neighborhood Development  DSS
# 287832  2015    5                      Culture & Recreation  LIB
# 287833  2014    2   Public Works, Transportation & Commerce  HHP
# 287834  2013    1                         Public Protection  JUV
# 287835  2015    4                          Community Health  DPH
#
#                       Dept   UC  \
# 0            Public Health  250
# 1            Public Health   39
# 2        Assessor/Recorder   21
# 3                   Police  911
# 4         PUC Hetch Hetchy   21
# ...                    ...  ...
# 287831      Human Services  535
# 287832      Public Library  790
# 287833    PUC Hetch Hetchy    6
# 287834  Juvenile Probation  250
# 287835       Public Health  791
#
#                                                   Union  \
# 0                     SEIU - Health Workers, Local 1021
# 1                        Stationary Engineers, Local 39
# 2       Prof & Tech Engineers - Miscellaneous, Local 21
# 3                          Police Officers' Association
# 4       Prof & Tech Engineers - Miscellaneous, Local 21
# ...                                                 ...
# 287831                SEIU - Human Services, Local 1021
# 287832                 SEIU - Miscellaneous, Local 1021
# 287833                      Electrical Workers, Local 6
# 287834                SEIU - Health Workers, Local 1021
# 287835     SEIU - Staff and Per Diem Nurses, Local 1021
#
#                              JF                             Job     EI  \
# 0       Med Therapy & Auxiliary                Morgue Attendant   6725
# 1              Journeyman Trade             Stationary Engineer  25058
# 2          Appraisal & Taxation  Senior Real Property Appraiser  46108
# 3               Police Services                      Sergeant 3  33369
# 4           Information Systems             IS Engineer-Journey  28684
# ...                         ...                             ...    ...
# 287831           Human Services       Senior Eligibility Worker   9610
# 287832                  Library                     Librarian 1    790
# 287833         Journeyman Trade     Electronic Maintenance Tech  38352
# 287834   Housekeeping & Laundry                          Porter  29266
# 287835                  Nursing                   Special Nurse  13906
#
#         Salaries  Overtime       H/D        YT  Total_Compensation
# 0          12196         0      0.00  Calendar               16158
# 1          74639      2820  12703.31    Fiscal              115784
# 2         100554         0  12424.50  Calendar              144708
# 3         140164     52754  13043.87    Fiscal              242323
# 4          58813         0   7655.28  Calendar               82106
# ...          ...       ...       ...       ...                 ...
# 287831     78980     30115  13068.80    Fiscal              147079
# 287832     30704         0   5465.57  Calendar               40174
# 287833    104451         0  13054.94  Calendar              164669
# 287834     14425         0   4051.90  Calendar               19594
# 287835    105561      8945   7993.89    Fiscal              154197
#
# [287836 rows x 15 columns]

# %%
print('Their are, \n{} rows and \n{} columns with \n{} employee data'.format(df.shape[0],df.shape[1],df.EI.unique().size))
# Out:
# Their are,
# 287836 rows and
# 15 columns with
# 52403 employee data

# %%
df.describe()
# Out:
#                 Year            OGC             UC             EI  \
# count  287836.000000  287836.000000  287836.000000  287836.000000
# mean     2014.250104       2.976007     490.540186   26913.060020
# std         1.016282       1.575586     333.238723   15539.719696
# min      2013.000000       1.000000       1.000000       1.000000
# 25%      2013.000000       2.000000     236.000000   13434.000000
# 50%      2014.000000       2.000000     535.000000   27013.000000
# 75%      2015.000000       4.000000     790.000000   40397.250000
# max      2016.000000       7.000000     990.000000   53794.000000
#
#             Salaries       Overtime            H/D  Total_Compensation
# count  287836.000000  287836.000000  287836.000000       287836.000000
# mean    63262.713139    4401.037115    8932.876472        97990.329882
# std     44638.657748   11079.137749    4894.072024        67750.020573
# min    -68771.000000  -12308.000000   -2940.470000       -74082.000000
# 25%     23406.000000       0.000000    4358.347500        35977.000000
# 50%     62504.500000       0.000000   11982.035000        98033.000000
# 75%     93000.250000    2738.000000   12801.790000       142138.250000
# max    515101.000000  227313.000000   21872.800000       653498.000000

# %%
df.dtypes
# Out:
# Year                    int64
# OGC                     int64
# OG                     object
# DC                     object
# Dept                   object
# UC                      int64
# Union                  object
# JF                     object
# Job                    object
# EI                      int64
# Salaries                int64
# Overtime                int64
# H/D                   float64
# YT                     object
# Total_Compensation      int64
# dtype: object

# %%
# Converting year column to datetime object
df['Year']=pd.to_datetime(df.Year, format='%Y')

# %%
df.dtypes
# Out:
# Year                  datetime64[ns]
# OGC                            int64
# OG                            object
# DC                            object
# Dept                          object
# UC                             int64
# Union                         object
# JF                            object
# Job                           object
# EI                             int64
# Salaries                       int64
# Overtime                       int64
# H/D                          float64
# YT                            object
# Total_Compensation             int64
# dtype: object

# %%
# As EI represents Employee identifier (or Id) setting it as index for dataset
df.set_index('EI',inplace=True)

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Year                   0
# OGC                    0
# OG                     0
# DC                     0
# Dept                   0
# UC                     0
# Union                 36
# JF                    38
# Job                    0
# Salaries               0
# Overtime               0
# H/D                    0
# YT                     0
# Total_Compensation     0
# dtype: int64

# %%
df[df['Union'].isnull()].head()
# Out:
#             Year  OGC                                       OG   DC  \
# EI
# 13880 2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 47943 2016-01-01    5                     Culture & Recreation  REC
# 41454 2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 7879  2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 32368 2016-01-01    2  Public Works, Transportation & Commerce  MTA
#
#                                   Dept   UC Union   JF  \
# EI
# 13880  Municipal Transportation Agency  790   NaN  NaN
# 47943   Recreation and Park Commission  790   NaN  NaN
# 41454  Municipal Transportation Agency  790   NaN  NaN
# 7879   Municipal Transportation Agency  790   NaN  NaN
# 32368  Municipal Transportation Agency  790   NaN  NaN
#
#                                      Job  Salaries  Overtime      H/D      YT  \
# EI
# 13880  Transportation Controller Trainee     28416         0  3940.59  Fiscal
# 47943      Recreation Facility Assistant      8060         0  2849.45  Fiscal
# 41454  Transportation Controller Trainee     20502       468  2843.22  Fiscal
# 7879   Transportation Controller Trainee     14028      1486  1945.36  Fiscal
# 32368  Transportation Controller Trainee     28416      4703  3940.59  Fiscal
#
#        Total_Compensation
# EI
# 13880               42123
# 47943               13515
# 41454               30612
# 7879                22849
# 32368               47277

# %%
# It can be seen that the Union with UC(Union code) is missing
# Checking for Union with UC=790
df[df['UC']==790].head(1)
# Out:
#            Year  OGC                                OG   DC  \
# EI
# 7385 2014-01-01    6  General Administration & Finance  TTX
#
#                          Dept   UC                             Union       JF  \
# EI
# 7385  Treasurer/Tax Collector  790  SEIU - Miscellaneous, Local 1021  Revenue
#
#                              Job  Salaries  Overtime       H/D      YT  \
# EI
# 7385  Senior Collections Officer     71466         0  12512.55  Fiscal
#
#       Total_Compensation
# EI
# 7385              105849

# %%
# So UC 790 is 'SEIU - Miscellaneous, Local 1021'

# %%
# Checking how many column with Union missing are of same UC
len(df[(df['Union'].isnull()) & (df['UC']==790)])
# Out:
# 36

# %%
# since every missing value in Union is of same type, imputing them with 'SEIU - Miscellaneous, Local 1021'

df['Union'].fillna('SEIU - Miscellaneous, Local 1021',inplace=True)

# %%
# Now for JF column
df[df['JF'].isnull()].head()
# Out:
#             Year  OGC                                       OG   DC  \
# EI
# 13880 2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 47943 2016-01-01    5                     Culture & Recreation  REC
# 41454 2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 7879  2016-01-01    2  Public Works, Transportation & Commerce  MTA
# 32368 2016-01-01    2  Public Works, Transportation & Commerce  MTA
#
#                                   Dept   UC                             Union  \
# EI
# 13880  Municipal Transportation Agency  790  SEIU - Miscellaneous, Local 1021
# 47943   Recreation and Park Commission  790  SEIU - Miscellaneous, Local 1021
# 41454  Municipal Transportation Agency  790  SEIU - Miscellaneous, Local 1021
# 7879   Municipal Transportation Agency  790  SEIU - Miscellaneous, Local 1021
# 32368  Municipal Transportation Agency  790  SEIU - Miscellaneous, Local 1021
#
#         JF                                Job  Salaries  Overtime      H/D  \
# EI
# 13880  NaN  Transportation Controller Trainee     28416         0  3940.59
# 47943  NaN      Recreation Facility Assistant      8060         0  2849.45
# 41454  NaN  Transportation Controller Trainee     20502       468  2843.22
# 7879   NaN  Transportation Controller Trainee     14028      1486  1945.36
# 32368  NaN  Transportation Controller Trainee     28416      4703  3940.59
#
#            YT  Total_Compensation
# EI
# 13880  Fiscal               42123
# 47943  Fiscal               13515
# 41454  Fiscal               30612
# 7879   Fiscal               22849
# 32368  Fiscal               47277

# %%
# Since JF is related to Job checking for values
df[df['JF'].isnull()]['Job'].unique()
# Out:
# array(['Transportation Controller Trainee',
#        'Recreation Facility Assistant', 'Managing Director'], dtype=object)

# %%
# The above three Job are missing their JF
# Checking for their JF in the dataframe
df[(df['Job']=='Transportation Controller Trainee') & df['JF'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Year, OGC, OG, DC, Dept, UC, Union, JF, Job, Salaries, Overtime, H/D, YT, Total_Compensation]
# Index: []

# %%
df[(df['Job']=='Recreation Facility Assistant') & df['JF'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Year, OGC, OG, DC, Dept, UC, Union, JF, Job, Salaries, Overtime, H/D, YT, Total_Compensation]
# Index: []

# %%
df[(df['Job']=='Managing Director') & df['JF'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Year, OGC, OG, DC, Dept, UC, Union, JF, Job, Salaries, Overtime, H/D, YT, Total_Compensation]
# Index: []

# %%
# Every missing job doesnt have JF in existing dataframe
# Checking the relative JF from the dataframe and imputing the missing values with it

df.JF.unique()
# Out:
# array(['Med Therapy & Auxiliary', 'Journeyman Trade',
#        'Appraisal & Taxation', 'Police Services', 'Information Systems',
#        'Revenue', 'Community Development', 'Recreation',
#        'Public Service Aide', 'Nursing', 'Fire Services',
#        'Professional Engineering', 'Protection & Apprehension',
#        'Housekeeping & Laundry', 'Street Transit', 'Dietary & Food',
#        'Library', 'Agriculture & Horticulture', 'SF Superior Court',
#        'Correction & Detention', 'Clerical, Secretarial & Steno',
#        'Human Services', 'Skilled Labor', 'Lab, Pharmacy & Med Techs',
#        'Budget, Admn & Stats Analysis', 'Personnel', 'Management',
#        'Payroll, Billing & Accounting', 'Health & Sanitation Inspection',
#        'Computer Operatns & Repro Svcs', 'Public Health', 'Legal & Court',
#        'Public Safety Inspection', 'Probation & Parole',
#        'Supervisory-Labor & Trade', 'Hospital Administration',
#        'Medical & Dental', 'Pub Relations & Spec Assts',
#        'Purchasing & Storekeeping', 'Park & Zoo',
#        'Administrative-DPW/PUC', 'Semi-Skilled & General Labor',
#        'Construction Project Mgmt', 'Energy & Environment',
#        'Sub-Professional Engineering', 'Airport Operation',
#        'Property Administration', 'Construction Inspection',
#        'Museum & Cultural Affairs', 'Administrative & Mgmt (Unrep)',
#        'Administrative-Labor & Trades', 'Administrative Secretarial',
#        'Emergency Services', nan, 'Port Operation',
#        'SF Redevelopment Agency'], dtype=object)

# %%
# The 'Transportation Controller Trainee' matches to "Street Transit"
#     'Recreation Facility Assistant' to "Recreation"
#     'Managing Director' to "Administrative & Mgmt (Unrep)"
# Imputing as above
df[(df['JF'].isnull()) & (df['Job']=='Transportation Controller Trainee')] = df[(df['JF'].isnull()) & (df['Job']=='Transportation Controller Trainee')].fillna('Street Transit')
df[(df['JF'].isnull()) & (df['Job']=='Recreation Facility Assistant')] = df[(df['JF'].isnull()) & (df['Job']=='Recreation Facility Assistant')].fillna('Recreation')
df[(df['JF'].isnull()) & (df['Job']=='Managing Director')] = df[(df['JF'].isnull()) & (df['Job']=='Managing Director')].fillna('Administrative & Mgmt (Unrep)')

# %%
df.isnull().sum()
# Out:
# Year                  0
# OGC                   0
# OG                    0
# DC                    0
# Dept                  0
# UC                    0
# Union                 0
# JF                    0
# Job                   0
# Salaries              0
# Overtime              0
# H/D                   0
# YT                    0
# Total_Compensation    0
# dtype: int64

# %%
# Now that all the null values are dealt eith lets move ahead

# %%
sns.distplot(df['OGC'],bins=7,kde=False)
# Out:
# c:\users\ukarj\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='OGC'>

# %% [markdown]
# `It can be seen that the OGC 2 has highest frequency`

# %%
# i,e.
df[df['OGC']==2].head(1)
# Out:
#             Year  OGC                                       OG   DC  \
# EI
# 28684 2013-01-01    2  Public Works, Transportation & Commerce  HHP
#
#                    Dept  UC                                            Union  \
# EI
# 28684  PUC Hetch Hetchy  21  Prof & Tech Engineers - Miscellaneous, Local 21
#
#                         JF                  Job  Salaries  Overtime      H/D  \
# EI
# 28684  Information Systems  IS Engineer-Journey     58813         0  7655.28
#
#              YT  Total_Compensation
# EI
# 28684  Calendar               82106

# %%
# There frequency of people from Public Works, Transportation & Commerce is highest

# %%
# The average spending of company throughout, groupedby year
df.groupby('Year').mean()[['Salaries','Total_Compensation']]
# Out:
#                 Salaries  Total_Compensation
# Year
# 2013-01-01  63894.330147        98141.315925
# 2014-01-01  62127.532228        97093.941524
# 2015-01-01  63019.503594        97971.129197
# 2016-01-01  64966.286659        99739.011877

# %%
#Choosing features

# %%
df.dtypes
# Out:
# Year                  datetime64[ns]
# OGC                            int64
# OG                            object
# DC                            object
# Dept                          object
# UC                             int64
# Union                         object
# JF                            object
# Job                           object
# Salaries                       int64
# Overtime                       int64
# H/D                          float64
# YT                            object
# Total_Compensation             int64
# dtype: object

# %%
# the OGC column represents OG column, similarly
#     DC column represents Dept column,
#     UC column represents Union column,
# similarly Job column is subclass of JF 
# Dropping OG,Dept,Union,Job columns from dataset after making a copy.
df_copy=df.copy()

df.drop(['OG','Dept','Union','Job'],axis=1,inplace=True)

# %%
df
# Out:
#             Year  OGC   DC   UC                       JF  Salaries  Overtime  \
# EI
# 6725  2015-01-01    4  DPH  250  Med Therapy & Auxiliary     12196         0
# 25058 2013-01-01    4  DPH   39         Journeyman Trade     74639      2820
# 46108 2015-01-01    6  ASR   21     Appraisal & Taxation    100554         0
# 33369 2016-01-01    1  POL  911          Police Services    140164     52754
# 28684 2013-01-01    2  HHP   21      Information Systems     58813         0
# ...          ...  ...  ...  ...                      ...       ...       ...
# 9610  2016-01-01    3  DSS  535           Human Services     78980     30115
# 790   2015-01-01    5  LIB  790                  Library     30704         0
# 38352 2014-01-01    2  HHP    6         Journeyman Trade    104451         0
# 29266 2013-01-01    1  JUV  250   Housekeeping & Laundry     14425         0
# 13906 2015-01-01    4  DPH  791                  Nursing    105561      8945
#
#             H/D        YT  Total_Compensation
# EI
# 6725       0.00  Calendar               16158
# 25058  12703.31    Fiscal              115784
# 46108  12424.50  Calendar              144708
# 33369  13043.87    Fiscal              242323
# 28684   7655.28  Calendar               82106
# ...         ...       ...                 ...
# 9610   13068.80    Fiscal              147079
# 790     5465.57  Calendar               40174
# 38352  13054.94  Calendar              164669
# 29266   4051.90  Calendar               19594
# 13906   7993.89    Fiscal              154197
#
# [287836 rows x 10 columns]

# %%
# the OGC and UC columns are of type int but should be object as they are codes representing category
df['OGC'] = df['OGC'].astype(object)
df['UC'] = df['UC'].astype(object)

# %%
# Checking and removing outliers

# %%
sns.boxplot(df['Salaries'])
# Out:
# c:\users\ukarj\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Salaries'>

# %%
df[df['Salaries']>200000].shape[0]
# Out:
# 1344

# %%
# There are 1344 outliers in Salaries column removing them
df=df[df['Salaries']<200000]

# %%
# As EI as index may lead to errors in future resetting index
df.reset_index(inplace=True)

# %%
df.drop(['EI'],axis=1,inplace=True)
# Out:
# c:\users\ukarj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# with z-score
z=np.abs(stats.zscore(df['Salaries']))

# %%
# Removing datapoints with zscore > 3 
df = df[(z < 3)].reset_index(drop=True)

# %%
z=np.abs(stats.zscore(df['Overtime']))

# %%
df.shape[0]*0.003  # The number of datapoints which are more than 3 Standard deviations away from mean
# Out:
# 857.742

# %%
z[z>7].size  # The threshold of 7 has 639 points
# Out:
# 639

# %%
df = df[(z < 7)].reset_index(drop=True)

# %%
df.groupby('Year').mean()
# Out:
#                 Salaries     Overtime          H/D  Total_Compensation
# Year
# 2013-01-01  62861.485042  4052.524162  9080.927519        96592.049060
# 2014-01-01  61247.683628  4192.013580  8888.680787        95754.226707
# 2015-01-01  61695.657788  4232.925544  8596.377238        96000.946781
# 2016-01-01  63336.941959  4546.297005  9133.810823        97260.839161

# %%
# There is not much significant effect of year on Salaries or Total_Compensation hence dropping it
df.drop(['Year'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#             Salaries       Overtime            H/D  Total_Compensation
# count  285275.000000  285275.000000  285275.000000       285275.000000
# mean    62115.720393    4209.307104    8895.966870        96264.244767
# std     42912.033591   10113.698301    4898.673574        65447.083385
# min    -18437.000000  -12308.000000   -2940.470000       -24362.000000
# 25%     23016.000000       0.000000    4300.770000        35302.500000
# 50%     62162.000000       0.000000   11925.270490        97320.000000
# 75%     91895.500000    2725.000000   12801.790000       140642.000000
# max    192523.000000   82044.000000   21872.800000       510574.000000

# %%
#The dataset contains rows with negative values in place on Salaries which acts as a outlier thus removed

# %%
df=df[df['Salaries']>0]

# %%
df.describe()
# Out:
#             Salaries       Overtime            H/D  Total_Compensation
# count  281850.000000  281850.000000  281850.000000       281850.000000
# mean    62871.040401    4259.562242    9004.013252        97335.846688
# std     42618.039271   10164.071190    4828.678533        65072.525342
# min         1.000000  -12308.000000    -272.780000        -8965.000000
# 25%     24566.000000       0.000000    4587.380000        37792.250000
# 50%     62700.000000       0.000000   12019.685000        98259.000000
# 75%     92338.500000    2831.000000   12801.790000       141297.750000
# max    192523.000000   82044.000000   21872.800000       510574.000000

# %%
df[df['Overtime']<0]
# Out:
#        OGC   DC   UC                             JF  Salaries  Overtime  \
# 9288     2  HHP   21                     Management      3427     -1072
# 32857    3  DSS    1            Public Service Aide     23093       -11
# 37860    4  DPH  250                        Nursing     57027      -213
# 68544    2  CWP   21         Administrative-DPW/PUC    131540      -487
# 81019    1  DAT  790                  Legal & Court     38851      -263
# 107966   2  MTA   21       Professional Engineering      7305      -309
# 112185   6  ADM  790            Public Service Aide      3173       -60
# 113771   4  DPH  791                        Nursing    101125    -12308
# 120304   3  DSS  535                 Human Services     12512       -23
# 145217   6  ADM  790  Clerical, Secretarial & Steno     65201      -121
# 149069   3  DSS  535                 Human Services     12195       -23
# 156605   3  DSS  535                 Human Services     42635       -51
# 171607   4  DPH  250                        Nursing     72002       -56
# 185772   4  DPH  790      Lab, Pharmacy & Med Techs    120595      -327
# 203101   2  MTA  790      Protection & Apprehension     57667      -110
# 219430   1  FIR  798                  Fire Services     18521      -311
# 223196   6  ADM  790                  Legal & Court      4959      -130
# 232124   3  DSS  535                 Human Services     12628       -51
# 242804   5  LIB  790  Budget, Admn & Stats Analysis     13677       -45
# 247129   1  DAT  790                  Legal & Court      4736      -263
# 247850   2  HHP   21                     Management     14773     -1072
# 248447   3  DSS    1            Public Service Aide     22710       -41
# 265504   4  DPH  790      Purchasing & Storekeeping       586       -61
# 271834   6  ADM  790                  Legal & Court     61288       -18
#
#                  H/D        YT  Total_Compensation
# 9288      287.070000  Calendar                3653
# 32857   10213.130000    Fiscal               38110
# 37860   13018.930000    Fiscal               88460
# 68544   12512.550000    Fiscal              180437
# 81019    6690.110000  Calendar               56475
# 107966   1167.420000    Fiscal               10367
# 112185   1021.730000    Fiscal                4375
# 113771   7394.570000    Fiscal              115924
# 120304   2985.234032  Calendar               19729
# 145217  12512.550000    Fiscal               96770
# 149069   2935.039878  Calendar               19015
# 156605   9366.440000    Fiscal               67132
# 171607  12512.550000    Fiscal              111275
# 185772  13087.520000    Fiscal              169364
# 203101  12452.650000    Fiscal               89489
# 219430   1945.360000    Fiscal               26498
# 223196   1363.310000    Fiscal                7796
# 232124   3012.680000  Calendar               19909
# 242804   3132.960000    Fiscal               20428
# 247129    814.210000    Fiscal                6770
# 247850   1198.520000    Fiscal               19191
# 248447  10040.100000    Fiscal               37316
# 265504    149.640000    Fiscal                4134
# 271834  12482.640000    Fiscal               93879

# %%
# Negative Overtime could mean deduction from the salary due to some reasons, so these are ignored except for the one with minimum Overtime of -12308 which acts as an outlier
df=df[df.Overtime != -12308].reset_index(drop=True)

# %%
df[df['Total_Compensation']<0]
# Out:
#        OGC   DC   UC          JF  Salaries  Overtime       H/D        YT  \
# 19508    4  DPH  791     Nursing      4658         0  0.000000  Calendar
# 24176    4  DPH  791     Nursing       329         0  0.000000    Fiscal
# 40980    4  DPH  791     Nursing     12329         0  0.000000  Calendar
# 54406    4  DPH  791     Nursing      2050         0  0.000000    Fiscal
# 55425    5  REC  790  Recreation       732         0  0.000000    Fiscal
# 58100    4  DPH  791     Nursing     16493         0  0.000000    Fiscal
# 88711    4  DPH  791     Nursing         7         0  3.897454  Calendar
# 92175    4  DPH  791     Nursing      4945         0  0.000000    Fiscal
# 134930   5  REC  790  Recreation       399         0  0.000000  Calendar
# 151644   4  DPH  791     Nursing      1703         0  0.000000  Calendar
# 166317   5  REC  790  Recreation         2         0 -5.585514  Calendar
# 206753   5  REC  790  Recreation        47         0  0.000000    Fiscal
#
#         Total_Compensation
# 19508                 -662
# 24176                -1357
# 40980                -8965
# 54406                -2364
# 55425                 -749
# 58100                -3320
# 88711                 -268
# 92175                -1931
# 134930                -598
# 151644               -2815
# 166317                  -3
# 206753                -176

# %%
# Total_Compensation can be due to various other reasons unrelated to Salaries or other features hence ignored

# %%
Num_Features=['Salaries','Overtime','H/D']

# %%
#seperating the target column
Y=df['Total_Compensation']
df.drop(['Total_Compensation'],axis=1,inplace=True)

# %%
# Modelling on just Numerical features
df_X = df[Num_Features]

# %%
scaler=StandardScaler()
x_scaled = scaler.fit_transform(df_X)

# %%
# Splitting the dataframe into training and testing
x_train,x_test,y_train,y_test=train_test_split(x_scaled,Y,test_size=0.25,random_state=7)

# %%
x_train.shape
# Out:
# (211386, 3)

# %%
x_test.shape
# Out:
# (70463, 3)

# %%
# Model
lin_model = LinearRegression()
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction & Scoring on train data
y_train_pred = lin_model.predict(x_train)


rmse = np.sqrt(mean_squared_error(y_train,y_train_pred))
r2 = r2_score(y_train,y_train_pred)
print('Scores of Model on Training data \nRMSE Score : {}\nR2 Score : {}'.format(rmse,r2))
# Out:
# Scores of Model on Training data
# RMSE Score : 7197.213899928682
# R2 Score : 0.9877357256418233

# %%
# prediction & scoring on test data
y_test_pred = lin_model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test,y_test_pred))
r2 = r2_score(y_test,y_test_pred)
print('Scores of Model on Testing data \nRMSE Score : {}\nR2 Score : {}'.format(rmse,r2))
# Out:
# Scores of Model on Testing data
# RMSE Score : 7211.443875511701
# R2 Score : 0.9878111027686998

# %%
y_test_pred
# Out:
# array([ 43869.20469281, 104256.672215  , 138798.26178987, ...,
#         12798.16830559,  89189.53170428,  12423.88182244])
